# %% [markdown]
# 데이터 : "교통정보.csv"
# 출처 : https://www.bigdata-transportation.kr/frn/prdt/detail?prdtId=PRDTNUM_000000000023
#
# 데이터 : "시간대별 교통량.csv"
# 출처 : https://gits.gg.go.kr/gtdb/web/trafficDb/trafficVolume/alwaysTrafficVolumeHighway.do

# %%
import pandas as pd

# %%
"""
아직 활용 어떻게 할지 못정함
"""
df=pd.read_csv("data/교통정보.csv")
df.columns=["집계일자","장비 ID","차로 유형","이동량","차량 점유율","평균속도","데이터 총 수","보정된 데이터 총 수","최종 변경 시각"]
df
# Out:
#           집계일자         장비 ID  차로 유형    이동량  차량 점유율    평균속도  데이터 총 수  \
# 0     20231102  1020VDS01500      1     -1   -1.00   -1.00        0
# 1     20231102  0552VDS01520      1  37479    6.57  103.48     2477
# 2     20231102  0010VDE17900      1  17796    3.06   89.80     2879
# 3     20231102  4000VDS00001      1  40118   10.99   94.06     2871
# 4     20231102  0650VDS02300      1  11067    2.14  107.23     2879
# ...        ...           ...    ...    ...     ...     ...      ...
# 7783  20231102  0010VDS30340      2   5885    5.89   93.07     1675
# 7784  20231102  0010VDS31680      2   6567   10.42   91.03     1674
# 7785  20231102  0010VDS30640      2   6900    5.97   87.24     1677
# 7786  20231102  0010VDE30301      2     80    1.01   59.34        0
# 7787  20231102  0010VDE29630      2     -1   -1.00   -1.00        0
#
#       보정된 데이터 총 수        최종 변경 시각
# 0               0  20231103035418
# 1               0  20231103035418
# 2               1  20231103035418
# ...

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
#
# 이거는 위에 있는 데이터에 대한 설명

# %% [markdown]
# # 여기서부터 보면 됨

# %%
# 시간대별 중부고속도로 교통량 (하남JC-경기광주IC)
time=pd.read_excel('시간대별 교통량.xlsx')
time
# Out:
#          노선명            구간명  방향    차로          날짜 00~01시 01~02시 02~03시 03~04시  \
# 0     중부고속도로  경기광주IC-경기광주JC  하행  일반차로  2022-01-01    360    360    341    413
# 1     중부고속도로    산곡JC-경기광주IC  하행  일반차로  2022-01-01    501    510    379    417
# 2     중부고속도로     동서울TG-산곡JC  하행  일반차로  2022-01-01    954   1042    843   1006
# 3     중부고속도로     하남IC-동서울TG  하행  일반차로  2022-01-01   1007   1084    860   1036
# 4     중부고속도로      하남JC-하남IC  하행  일반차로  2022-01-01   1049   1199    910   1083
# ...      ...            ...  ..   ...         ...    ...    ...    ...    ...
# 1775  중부고속도로  경기광주IC-경기광주JC  하행  일반차로  2022-12-31    289    266    207    230
# 1776  중부고속도로    산곡JC-경기광주IC  하행  일반차로  2022-12-31    476    382    285    273
# 1777  중부고속도로     동서울TG-산곡JC  하행  일반차로  2022-12-31    781    503    412    469
# 1778  중부고속도로     하남IC-동서울TG  하행  일반차로  2022-12-31    759    530    431    479
# 1779  중부고속도로      하남JC-하남IC  하행  일반차로  2022-12-31    786    602    476    547
#
# ...

# %%
#천호대로,하남대로,회안대로 교통량
