# %% [markdown]
# 데이터 : "5분당_교통량(등교)통합.csv"
# 출처 : https://www.bigdata-transportation.kr/frn/prdt/detail?prdtId=PRDTNUM_000000000007
#
# 데이터 : "시간대별 교통량.csv"
# 출처 : https://gits.gg.go.kr/gtdb/web/trafficDb/trafficVolume/alwaysTrafficVolumeHighway.do

# %%
import pandas as pd

# %%
# 시간대별 중부고속도로 교통량 (하남JC-경기광주IC) ,엑셀로 preprocessing함
time=pd.read_excel('data/시간대별 교통량.xlsx')
time
# Out:
#          노선명          구간명          날짜   월 요일 00~01시 01~02시 02~03시 03~04시  \
# 0     중부고속도로  산곡JC-경기광주IC  2022-01-01   1  토    501    510    379    417
# 1     중부고속도로   동서울TG-산곡JC  2022-01-01   1  토    954   1042    843   1006
# 2     중부고속도로   하남IC-동서울TG  2022-01-01   1  토   1007   1084    860   1036
# 3     중부고속도로  산곡JC-경기광주IC  2022-01-02   1  일    230    183    157    157
# 4     중부고속도로   동서울TG-산곡JC  2022-01-02   1  일    345    270    190    211
# ...      ...          ...         ...  .. ..    ...    ...    ...    ...
# 1063  중부고속도로   동서울TG-산곡JC  2022-12-30  12  금    588    424    386    410
# 1064  중부고속도로   하남IC-동서울TG  2022-12-30  12  금    604    440    380    400
# 1065  중부고속도로  산곡JC-경기광주IC  2022-12-31  12  토    476    382    285    273
# 1066  중부고속도로   동서울TG-산곡JC  2022-12-31  12  토    781    503    412    469
# 1067  중부고속도로   하남IC-동서울TG  2022-12-31  12  토    759    530    431    479
#
#      04~05시  ... 15~16시 16~17시 17~18시 18~19시 19~20시 20~21시 21~22시 22~23시  \
# ...

# %%
time.head(10)
# Out:
#       노선명          구간명          날짜  월 요일 00~01시 01~02시 02~03시 03~04시 04~05시  \
# 0  중부고속도로  산곡JC-경기광주IC  2022-01-01  1  토    501    510    379    417    520
# 1  중부고속도로   동서울TG-산곡JC  2022-01-01  1  토    954   1042    843   1006   1126
# 2  중부고속도로   하남IC-동서울TG  2022-01-01  1  토   1007   1084    860   1036   1130
# 3  중부고속도로  산곡JC-경기광주IC  2022-01-02  1  일    230    183    157    157    200
# 4  중부고속도로   동서울TG-산곡JC  2022-01-02  1  일    345    270    190    211    306
# 5  중부고속도로   하남IC-동서울TG  2022-01-02  1  일    319    221    156    169    267
# 6  중부고속도로  산곡JC-경기광주IC  2022-01-03  1  월    312    251    205    250    464
# 7  중부고속도로   동서울TG-산곡JC  2022-01-03  1  월    519    407    369    501   1040
# 8  중부고속도로   하남IC-동서울TG  2022-01-03  1  월    484    362    292    482   1068
# 9  중부고속도로  산곡JC-경기광주IC  2022-01-04  1  화    379    295    250    256    387
#
#    ... 15~16시 16~17시 17~18시 18~19시 19~20시 20~21시 21~22시 22~23시 23~24시 전일합계(대)
# ...
